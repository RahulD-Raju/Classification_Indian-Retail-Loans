# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
profile_df = pd.read_csv('./data/Training Data.csv')

# %% [markdown]
# # Data Inspection & Cleaning

# %%
profile_df
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
profile_df.sample(10)
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 26570    26571  8658161   79          13         single          rented
# 69444    69445  3756692   33           4         single          rented
# 182289  182290  8660614   24          18         single          rented
# 31906    31907  6654390   67          15         single          rented
# 228894  228895  5311172   65           9         single          rented
# 129345  129346  9768584   52          14        married          rented
# 234881  234882  3649311   22           8         single          rented
# 27136    27137  3562528   58           9         single          rented
# 7769      7770  5341055   57           8         single          rented
# 194324  194325  3559810   32           7         single          rented
#
#        Car_Ownership                  Profession                  CITY  \
# 26570             no                  Politician             Ozhukarai
# ...

# %%
# no null values
# data are all of the appropriate data-type
profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 252000 non-null  int64
#  1   Income             252000 non-null  int64
#  2   Age                252000 non-null  int64
#  3   Experience         252000 non-null  int64
#  4   Married/Single     252000 non-null  object
#  5   House_Ownership    252000 non-null  object
#  6   Car_Ownership      252000 non-null  object
#  7   Profession         252000 non-null  object
#  8   CITY               252000 non-null  object
#  9   STATE              252000 non-null  object
#  10  CURRENT_JOB_YRS    252000 non-null  int64
#  11  CURRENT_HOUSE_YRS  252000 non-null  int64
#  12  Risk_Flag          252000 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 25.0+ MB

# %%
# Summary stats of quantitative features appears to be in line

profile_df.describe()
# Out:
#                   Id        Income            Age     Experience  \
# count  252000.000000  2.520000e+05  252000.000000  252000.000000
# mean   126000.500000  4.997117e+06      49.954071      10.084437
# std     72746.278255  2.878311e+06      17.063855       6.002590
# min         1.000000  1.031000e+04      21.000000       0.000000
# 25%     63000.750000  2.503015e+06      35.000000       5.000000
# 50%    126000.500000  5.000694e+06      50.000000      10.000000
# 75%    189000.250000  7.477502e+06      65.000000      15.000000
# max    252000.000000  9.999938e+06      79.000000      20.000000
#
#        CURRENT_JOB_YRS  CURRENT_HOUSE_YRS      Risk_Flag
# count    252000.000000      252000.000000  252000.000000
# mean          6.333877          11.997794       0.123000
# std           3.647053           1.399037       0.328438
# min           0.000000          10.000000       0.000000
# 25%           3.000000          11.000000       0.000000
# ...

# %%
# Insure correct formatting of columns

profile_df.columns
# Out:
# Index(['Id', 'Income', 'Age', 'Experience', 'Married/Single',
#        'House_Ownership', 'Car_Ownership', 'Profession', 'CITY', 'STATE',
#        'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag'],
#       dtype='object')

# %%
# Check for duplicates
profile_df.groupby(['Id', 'Income','Age']).Experience.count().reset_index().sort_values('Id', ascending=False)
# Out:
#             Id   Income  Age  Experience
# 251999  252000  9070230   70           1
# 251998  251999  6507128   45           1
# 251997  251998  4522448   46           1
# 251996  251997  2843572   26           1
# 251995  251996  8154883   43           1
# ...        ...      ...  ...         ...
# 4            5  5768871   47           1
# 3            4  6256451   41           1
# 2            3  3991815   66           1
# 1            2  7574516   40           1
# 0            1  1303834   23           1
#
# [252000 rows x 4 columns]

# %%
y = profile_df['Risk_Flag']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Target/Dependent Variable

# %%
# Data set is highly imbalanced, might have to make modifications to algorithms 

profile_df['Risk_Flag'].value_counts().plot.pie(autopct="%.1f%%", labels = ['Not Defaulted(0)', 'Defaulted(1)']);
plt.title('Target Class Distribution');
plt.ylabel(' ');

# %%
# 0 = Not Defaulted on Loan, 1 = Defaulted on Loan

profile_df['Risk_Flag'].value_counts()
# Out:
# 0    221004
# 1     30996
# Name: Risk_Flag, dtype: int64

# %% [markdown]
# #### 1) Income

# %%
#summary stats
profile_df['Income'].describe()
# Out:
# count    2.520000e+05
# mean     4.997117e+06
# std      2.878311e+06
# min      1.031000e+04
# 25%      2.503015e+06
# 50%      5.000694e+06
# 75%      7.477502e+06
# max      9.999938e+06
# Name: Income, dtype: float64

# %%
# Survey data to insure no oddities

profile_df[['Income']].sample(10)
# Out:
#          Income
# 89130   4620331
# 20721   5495848
# 165254  2139734
# 164805  5583816
# 231938  3370813
# 130770  5979967
# 92891   8143512
# 81788   2873313
# 18205   1798025
# 114762  9645128

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 12))  # 3 Rows, 1 Col

count0, bins_0, _ = ax[0].hist(profile_df.loc[(y==0),'Income'], bins=25, range=(0,10000000))
count1, bins_1, _ = ax[1].hist(profile_df.loc[(y==1),'Income'], bins=25, range=(0,10000000))
ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));
#sns.distplot(profile_df['Income'])

# %% [markdown]
#  #### 2) Age

# %%
#summary stats

profile_df['Age'].describe()
# Out:
# count    252000.000000
# mean         49.954071
# std          17.063855
# min          21.000000
# 25%          35.000000
# 50%          50.000000
# 75%          65.000000
# max          79.000000
# Name: Age, dtype: float64

# %%
# Survey data to insure no oddities

profile_df[['Age']].sample(10)
# Out:
#         Age
# 115663   53
# 100154   50
# 103669   34
# 161366   35
# 241299   63
# 78995    40
# 242227   71
# 57590    35
# 106446   25
# 183944   25

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 12))  # 3 Rows, 1 Col

count0, bins_0, _ = ax[0].hist(profile_df.loc[(y==0),'Age'], bins=25, range=(18,85))
count1, bins_1, _ = ax[1].hist(profile_df.loc[(y==1),'Age'], bins=25, range=(18,85))
ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));
# Out:
# <ipython-input-156-9dab14c346d8>:5: RuntimeWarning: invalid value encountered in true_divide
#   ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));

# %% [markdown]
# #### 3) Experience(number of years of professional experience)

# %%
profile_df['Experience'].describe()
# Out:
# count    252000.000000
# mean         10.084437
# std           6.002590
# min           0.000000
# 25%           5.000000
# 50%          10.000000
# 75%          15.000000
# max          20.000000
# Name: Experience, dtype: float64

# %%
# Survey data to insure no oddities

profile_df[['Experience']].sample(10)
# Out:
#         Experience
# 232466           8
# 100442          12
# 52146            5
# 40491           10
# 4981             5
# 20891           10
# 109560          13
# 19506           19
# 244098          17
# 143337          15

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 12))  # 3 Rows, 1 Col

count0, bins_0, _ = ax[0].hist(profile_df.loc[(y==0),'Experience'], bins=25, range=(0,25))
count1, bins_1, _ = ax[1].hist(profile_df.loc[(y==1),'Experience'], bins=25, range=(0,25))
ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));
# Out:
# <ipython-input-157-f301b6372a0d>:5: RuntimeWarning: invalid value encountered in true_divide
#   ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));

# %% [markdown]
# #### 4) Married/Single

# %%
profile_df['Married/Single'].value_counts()
# Out:
# single     226272
# married     25728
# Name: Married/Single, dtype: int64

# %%
# Survey data to insure no oddities

profile_df[['Married/Single']].sample(10)
# Out:
#        Married/Single
# 69374          single
# 162394         single
# 45751         married
# 164017         single
# 42229          single
# 28694          single
# 176366        married
# 187038         single
# 110982         single
# 104052         single

# %%
sns.histplot(profile_df['Married/Single'])
# Out:
# <AxesSubplot:xlabel='Married/Single', ylabel='Count'>

# %% [markdown]
# #### 5) House Ownership

# %%
# count of unique values
profile_df['House_Ownership'].value_counts()
# Out:
# rented          231898
# owned            12918
# norent_noown      7184
# Name: House_Ownership, dtype: int64

# %%
# Survey data to insure no oddities

profile_df[['House_Ownership']].sample(10)
# Out:
#        House_Ownership
# 15416           rented
# 245387          rented
# 246631          rented
# 2711            rented
# 150663          rented
# 161838          rented
# 16143           rented
# 52276           rented
# 163219          rented
# 146921          rented

# %%
sns.histplot(profile_df['House_Ownership'])
# Out:
# <AxesSubplot:xlabel='House_Ownership', ylabel='Count'>

# %% [markdown]
# #### 6) Car Ownership

# %%
# count of unique values
profile_df['Car_Ownership'].value_counts()
# Out:
# no     176000
# yes     76000
# Name: Car_Ownership, dtype: int64

# %%
# Survey data to insure no oddities

profile_df[['Car_Ownership']].sample(10)
# Out:
#        Car_Ownership
# 107893            no
# 5688              no
# 117497            no
# 3308             yes
# 180967            no
# 208248            no
# 53466            yes
# 15589             no
# 217680           yes
# 161180           yes

# %%
sns.histplot(profile_df['Car_Ownership'])
# Out:
# <AxesSubplot:xlabel='Car_Ownership', ylabel='Count'>

# %% [markdown]
# ### 7) Profession

# %%
profile_df['Profession'].value_counts()
# Out:
# Physician                     5957
# Statistician                  5806
# Web_designer                  5397
# Psychologist                  5390
# Computer_hardware_engineer    5372
# Drafter                       5359
# Magistrate                    5357
# Fashion_Designer              5304
# Air_traffic_controller        5281
# Comedian                      5259
# Industrial_Engineer           5250
# Mechanical_engineer           5217
# Chemical_engineer             5205
# Technical_writer              5195
# Hotel_Manager                 5178
# Financial_Analyst             5167
# Graphic_Designer              5166
# Flight_attendant              5128
# Biomedical_Engineer           5127
# Secretary                     5061
# Software_Developer            5053
# Petroleum_Engineer            5041
# Police_officer                5035
# Computer_operator             4990
# Politician                    4944
# Microbiologist                4881
# Technician                    4864
# ...

# %%
# Survey data to insure no oddities

profile_df[['Profession']].sample(10)
# Out:
#                  Profession
# 125224              Analyst
# 29037       Design_Engineer
# 20017           Firefighter
# 210012     Technical_writer
# 154098            Librarian
# 181278              Aviator
# 214881   Software_Developer
# 136336         Army_officer
# 207654  Biomedical_Engineer
# 215478         Army_officer

# %%
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(20)

profile_df['Profession'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 8) City

# %%
profile_df['CITY'].value_counts()
# Out:
# Vijayanagaram       1259
# Bhopal              1208
# Bulandshahr         1185
# Saharsa[29]         1180
# Vijayawada          1172
#                     ...
# Ujjain               486
# Warangal[11][12]     459
# Bettiah[33]          457
# Katni                448
# Karaikudi            431
# Name: CITY, Length: 317, dtype: int64

# %%
# "Erode[17]" seems odd

profile_df['CITY'].sample(10)
# Out:
# 73787     Bidhannagar
# 40287          Ambala
# 230335         Munger
# 186048      Amaravati
# 95480       Proddatur
# 115505          Malda
# 87695          Satara
# 251333    Navi_Mumbai
# 117475      Erode[17]
# 174810          Katni
# Name: CITY, dtype: object

# %%
# Replace "Erode[17]" with "Erode"

profile_df[profile_df['CITY'] == 'Erode[17]'].replace('Erode[17]', 'Erode[17]'.split('[')[0])
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 12          13  9120988   28           9         single          rented
# 25          26  1797876   76          20         single    norent_noown
# 618        619  6471065   68          10         single           owned
# 959        960  1900932   69          11         single          rented
# 961        962  8745080   55          18         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 250532  250533   265580   54           2         single          rented
# 250540  250541  5625416   61           6         single          rented
# 250991  250992  1542960   65           9         single          rented
# 251304  251305  3670032   32           5         single          rented
# 251343  251344  8310582   57           5         single          rented
#
#        Car_Ownership           Profession   CITY       STATE  CURRENT_JOB_YRS  \
# ...

# %% [markdown]
# #### 9)  State

# %%
profile_df['STATE'].sample(10)
# Out:
# 39191             Odisha
# 119151     Uttar_Pradesh
# 147076         Telangana
# 109464         Telangana
# 18496             Kerala
# 96807          Rajasthan
# 242251    Madhya_Pradesh
# 81869          Jharkhand
# 147011         Rajasthan
# 149375        Tamil_Nadu
# Name: STATE, dtype: object

# %%
profile_df['STATE'].value_counts()
# Out:
# Uttar_Pradesh        28400
# Maharashtra          25562
# Andhra_Pradesh       25297
# West_Bengal          23483
# Bihar                19780
# Tamil_Nadu           16537
# Madhya_Pradesh       14122
# Karnataka            11855
# Gujarat              11408
# Rajasthan             9174
# Jharkhand             8965
# Haryana               7890
# Telangana             7524
# Assam                 7062
# Kerala                5805
# Delhi                 5490
# Punjab                4720
# Odisha                4658
# Chhattisgarh          3834
# Uttarakhand           1874
# Jammu_and_Kashmir     1780
# Puducherry            1433
# Mizoram                849
# Manipur                849
# Himachal_Pradesh       833
# Tripura                809
# Uttar_Pradesh[5]       743
# Chandigarh             656
# Sikkim                 608
# Name: STATE, dtype: int64

# %%
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(20)

profile_df['STATE'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 10) Num of Years in Current Job(CURRENT_JOB_YRS)

# %%
profile_df['CURRENT_JOB_YRS'].describe()
# Out:
# count    252000.000000
# mean          6.333877
# std           3.647053
# min           0.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          14.000000
# Name: CURRENT_JOB_YRS, dtype: float64

# %%
profile_df['CURRENT_JOB_YRS'].sample(10)
# Out:
# 223012    10
# 51123      4
# 120934     9
# 138104     9
# 224355     5
# 185618     8
# 85304      3
# 167704     8
# 34948      4
# 197753     5
# Name: CURRENT_JOB_YRS, dtype: int64

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 12))  # 3 Rows, 1 Col

count0, bins_0, _ = ax[0].hist(profile_df.loc[(y==0),'CURRENT_JOB_YRS'], bins=14, range=(0,14))
count1, bins_1, _ = ax[1].hist(profile_df.loc[(y==1),'CURRENT_JOB_YRS'], bins=14, range=(0,14))
ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));

# %% [markdown]
# #### 11) Number of years living at current location(CURRENT_HOUSE_YRS)

# %%
profile_df['CURRENT_HOUSE_YRS'].describe()
# Out:
# count    252000.000000
# mean         11.997794
# std           1.399037
# min          10.000000
# 25%          11.000000
# 50%          12.000000
# 75%          13.000000
# max          14.000000
# Name: CURRENT_HOUSE_YRS, dtype: float64

# %%
profile_df['CURRENT_HOUSE_YRS'].sample(10)
# Out:
# 184825    11
# 85739     12
# 38764     13
# 249965    12
# 13384     10
# 131649    14
# 223815    13
# 5607      13
# 149526    11
# 88260     11
# Name: CURRENT_HOUSE_YRS, dtype: int64

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 12))  # 3 Rows, 1 Col

count0, bins_0, _ = ax[0].hist(profile_df.loc[(y==0),'CURRENT_HOUSE_YRS'], bins=5, range=(10,14))
count1, bins_1, _ = ax[1].hist(profile_df.loc[(y==1),'CURRENT_HOUSE_YRS'], bins=5, range=(10,14))
ax[2].plot((bins_0[:-1]+bins_0[1:])/2,count1/(count1 + count0));

# %%
# Create df of quantitative variables + target

quant_features = profile_df[['Income','Age','Experience','CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag' ]]

# %%
#Create pairplot with hue for target

sns.pairplot(quant_features.sample(20000), hue='Risk_Flag')

# %%
# Divide customer profile into feature and target, dispense with ID

feature_df = profile_df.loc[:, 'Income':'CURRENT_HOUSE_YRS']
target_df = profile_df[['Risk_Flag']]

# %%
# Save Cleaned DataFrame

profile_df.to_csv('./data/profile_df.csv')
